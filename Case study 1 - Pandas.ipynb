# %%
#use of csv - mainly used for bulk exports

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"/Users/arshita/Documents/Machine learning/Case study 1 salary gender/SalaryGender.csv")
df
# Out:
#     Salary  Gender  Age  PhD
# 0    140.0       1   47    1
# 1     30.0       0   65    1
# 2     35.1       0   56    0
# 3     30.0       1   23    0
# 4     80.0       0   53    1
# ..     ...     ...  ...  ...
# 95    18.6       1   26    0
# 96   152.0       1   56    1
# 97     1.8       1   28    0
# 98    35.0       0   44    0
# 99     4.0       0   24    0
#
# [100 rows x 4 columns]

# %%
df.describe()
# Out:
#            Salary      Gender         Age         PhD
# count  100.000000  100.000000  100.000000  100.000000
# mean    52.524500    0.500000   46.880000    0.390000
# std     42.220933    0.502519   15.271469    0.490207
# min      0.250000    0.000000   20.000000    0.000000
# 25%     20.000000    0.000000   31.500000    0.000000
# 50%     39.300000    0.500000   49.000000    0.000000
# 75%     75.500000    1.000000   60.000000    1.000000
# max    190.000000    1.000000   77.000000    1.000000

# %%
df.corr() 

#by default it's taking pearson correlation coefficent formula
# Out:
#           Salary    Gender       Age       PhD
# Salary  1.000000  0.259312  0.477043  0.555560
# Gender  0.259312  1.000000  0.160580  0.184521
# Age     0.477043  0.160580  1.000000  0.353081
# PhD     0.555560  0.184521  0.353081  1.000000

# %%
df.corr(method = 'kendall')

#here it's taking kendall tau correlation coefficient formula
#that's why values are different
# Out:
#           Salary    Gender       Age       PhD
# Salary  1.000000  0.145310  0.334499  0.477900
# Gender  0.145310  1.000000  0.159001  0.184521
# Age     0.334499  0.159001  1.000000  0.276267
# PhD     0.477900  0.184521  0.276267  1.000000

# %%
sns.heatmap(df.corr())
# Out:
# <Axes: >

# %%
sns.heatmap(df.corr(), cmap = "coolwarm", annot = True)
# Out:
# <Axes: >

# %%
sns.set(style = 'whitegrid')
sns.scatterplot(x = "Gender", y = "Salary", data = df)
# Out:
# <Axes: xlabel='Gender', ylabel='Salary'>

# %%
sns.scatterplot(data = df, x = 'Age', y = 'Salary', color = 'red')
# Out:
# <Axes: xlabel='Age', ylabel='Salary'>

# %%
sns.scatterplot(data = df, x = 'Age', y = 'Salary', hue = 'Gender')
# Out:
# <Axes: xlabel='Age', ylabel='Salary'>

# %%
sns.relplot(data = df, x = 'Age', y = 'Salary', hue = 'Gender', col = "PhD")

# %%
sns.lineplot(data = df, x = 'PhD', y = 'Salary', hue = 'Gender')
# Out:
# <Axes: xlabel='PhD', ylabel='Salary'>
